# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

c = pd.read_csv(r"C:\Users\MANI\Downloads\Churn_dataset.csv")
c
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
c.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3330.000000       3333.000000        3333.000000      3330.000000
# mean        100.420721         30.562307         200.980348       100.713213
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3330 non-null   float64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3330 non-null   float64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
c.shape
# Out:
# (3333, 21)

# %%
c.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1            110.0
# 1             yes                     26              161.6            123.0
# 2              no                      0              243.4            114.0
# 3              no                      0              299.4             71.0
# 4              no                      0              166.7            113.0
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
c.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           3
# total day charge          0
# total eve minutes         0
# total eve calls           3
# total eve charge          0
# total night minutes       0
# total night calls         5
# total night charge        0
# total intl minutes        0
# total intl calls          5
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
c.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls           float64
# total day charge          float64
# total eve minutes         float64
# total eve calls           float64
# total eve charge          float64
# total night minutes       float64
# total night calls         float64
# total night charge        float64
# total intl minutes        float64
# total intl calls          float64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
mani=c.select_dtypes(include=['float','bool'])
mani
# Out:
#       total day minutes  total day calls  total day charge  total eve minutes  \
# 0                 265.1            110.0             45.07              197.4
# 1                 161.6            123.0             27.47              195.5
# 2                 243.4            114.0             41.38              121.2
# 3                 299.4             71.0             50.90               61.9
# 4                 166.7            113.0             28.34              148.3
# ...                 ...              ...               ...                ...
# 3328              156.2             77.0             26.55              215.5
# 3329              231.1             57.0             39.29              153.4
# 3330              180.8            109.0             30.74              288.8
# 3331              213.8            105.0             36.35              159.6
# 3332              234.4            113.0             39.85              265.9
#
# ...

# %%
mani.shape
# Out:
# (3333, 13)

# %%
mani.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   total day minutes    3333 non-null   float64
#  1   total day calls      3330 non-null   float64
#  2   total day charge     3333 non-null   float64
#  3   total eve minutes    3333 non-null   float64
#  4   total eve calls      3330 non-null   float64
#  5   total eve charge     3333 non-null   float64
#  6   total night minutes  3333 non-null   float64
#  7   total night calls    3328 non-null   float64
#  8   total night charge   3333 non-null   float64
#  9   total intl minutes   3333 non-null   float64
#  10  total intl calls     3328 non-null   float64
#  11  total intl charge    3333 non-null   float64
#  12  churn                3333 non-null   bool
# dtypes: bool(1), float64(12)
# memory usage: 315.9 KB

# %%
import matplotlib.pyplot as plt

num_cols = [
    # 'total day minutes',
    'total day calls',
    # 'total day charge',
    'total eve calls',
    # 'total eve charge',
    # 'total eve minutes',
    'total night calls',
    # 'total night charge',
    # 'total night minutes',
    'total intl calls',
    # 'total intl charge',
    # 'total intl minutes'
]

plt.figure(figsize=(18,12))

for i, mani in enumerate(num_cols, 1):
    plt.subplot(2, 2, i)   # 4x4 grid
    plt.hist(c[mani], bins=20, edgecolor='black', color='red')
    plt.title(mani)
    plt.xlabel(mani)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
c.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           3
# total day charge          0
# total eve minutes         0
# total eve calls           3
# total eve charge          0
# total night minutes       0
# total night calls         5
# total night charge        0
# total intl minutes        0
# total intl calls          5
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
for i in ['total eve calls','total night calls']:
    c[i] = c[i].fillna(c[i].median())
c[i]
# Out:
# 0        91.0
# 1       103.0
# 2       104.0
# 3        89.0
# 4       121.0
#         ...
# 3328     83.0
# 3329    123.0
# 3330     91.0
# 3331    137.0
# 3332     77.0
# Name: total night calls, Length: 3333, dtype: float64

# %%
for i in ['total day calls','total intl calls']:
    c[i] = c[i].fillna(c[i].mean())
c[i]
# Out:
# 0        3.0
# 1        3.0
# 2        5.0
# 3        7.0
# 4        3.0
#         ...
# 3328     6.0
# 3329     4.0
# 3330     6.0
# 3331    10.0
# 3332     4.0
# Name: total intl calls, Length: 3333, dtype: float64

# %%
c.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
c.to_csv('new_data.csv',index=False)

# %%
df=pd.read_csv('new_data.csv')
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
c.to_csv('phones_calls.csv',index=False)

# %%
df=pd.read_csv('phones_calls.csv')
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# c.info()

# %%
num_cols = ['total day minutes','total eve calls','total night charge','total intl calls',]
plt.figure(figsize=(15,10))
for i, mani in enumerate(num_cols, 1):
    plt.subplot(3,2,i)
    sns.boxplot(x=c[mani], color="lightblue")
    # plt.title(f"Boxplot of {plot}")
    plt.xlabel(mani)
plt.tight_layout()
plt.show()

# %%
import numpy as np

# total day minutes
Q1 = np.percentile(c['total day minutes'], 25, method='midpoint')
Q2 = np.percentile(c['total day minutes'], 50, method='midpoint')
Q3 = np.percentile(c['total day minutes'], 75, method='midpoint')

print(Q1)
print(Q2)
print(Q3)

IQR1 = Q3 - Q1
print(IQR1)


# total eve calls
Q1 = np.percentile(c['total eve calls'], 25, method='midpoint')
Q2 = np.percentile(c['total eve calls'], 50, method='midpoint')
Q3 = np.percentile(c['total eve calls'], 75, method='midpoint')

print(Q1)
print(Q2)
print(Q3)

IQR2 = Q3 - Q1
print(IQR2)


# total night charge
Q1 = np.percentile(c['total night charge'], 25, method='midpoint')
Q2 = np.percentile(c['total night charge'], 50, method='midpoint')
Q3 = np.percentile(c['total night charge'], 75, method='midpoint')

print(Q1)
print(Q2)
print(Q3)

IQR3 = Q3 - Q1
print(IQR3)


# total intl calls
Q1 = np.percentile(c['total intl calls'], 25, method='midpoint')
Q2 = np.percentile(c['total intl calls'], 50, method='midpoint')
Q3 = np.percentile(c['total intl calls'], 75, method='midpoint')

print(Q1)
print(Q2)
print(Q3)

IQR4 = Q3 - Q1
print(IQR4)
# Out:
# 143.7
# 179.4
# 216.4
# 72.70000000000002
# 87.0
# 100.0
# 114.0
# 27.0
# 7.52
# 9.05
# 10.59
# 3.0700000000000003
# 3.0
# 4.0
# 6.0
# 3.0

# %%
lower_limit=Q1-1.2*IQR1
upper_limit=Q3+1.5*IQR1
print(upper_limit)
print(lower_limit)
# Out:
# 115.05000000000003
# -84.24000000000002

# %%
lower_limit=Q1-1.2*IQR2
upper_limit=Q3+1.5*IQR2
print(upper_limit)
print(lower_limit)
# Out:
# 46.5
# -29.4

# %%
outlier = []

for x in df['total day minutes']:
    if (x > upper_limit) or (x < lower_limit):
        outlier.append(x)

print(outlier)
# Out:
# [265.1, 161.6, 243.4, 299.4, 166.7, 223.4, 218.2, 157.0, 184.5, 258.6, 129.1, 187.7, 128.8, 156.6, 120.7, 332.9, 196.4, 190.7, 189.7, 224.4, 155.1, 62.4, 183.0, 110.4, 81.1, 124.3, 213.0, 134.3, 190.0, 119.3, 84.8, 226.1, 212.0, 249.6, 176.8, 220.0, 146.3, 130.8, 203.9, 140.4, 126.3, 173.1, 124.8, 85.8, 154.0, 120.9, 211.3, 187.0, 159.1, 133.2, 191.9, 220.6, 186.1, 160.2, 151.0, 175.5, 126.9, 198.4, 148.8, 229.3, 192.1, 268.6, 193.7, 180.7, 131.2, 148.1, 251.5, 125.2, 211.6, 178.9, 241.8, 224.9, 248.6, 203.4, 235.8, 157.1, 300.3, 61.6, 214.1, 170.2, 201.1, 215.4, 165.6, 249.5, 210.6, 179.3, 157.9, 214.3, 154.1, 237.9, 143.9, 203.4, 124.3, 252.9, 179.1, 278.4, 160.1, 198.2, 212.1, 251.8, 161.2, 178.3, 151.7, 135.0, 170.5, 238.1, 281.4, 117.9, 148.6, 229.8, 165.0, 185.0, 161.0, 126.7, 58.9, 196.8, 162.6, 282.5, 113.7, 239.8, 210.2, 213.8, 190.7, 170.9, 154.2, 201.4, 70.7, 187.5, 91.7, 214.2, 145.5, 166.3, 231.0, 200.3, 197.0, 129.9, 175.8, 203.1, 183.2, 205.0, 148.5, 200.3, 192.6, 246.
# ...

# %%
outlier = []

for x in c['total eve calls']:
    if (x > upper_limit) or (x < lower_limit):
        outlier.append(x)

print(outlier)
# Out:
# [99.0, 103.0, 110.0, 88.0, 122.0, 101.0, 108.0, 94.0, 100.0, 500.0, 148.0, 71.0, 75.0, 76.0, 97.0, 90.0, 111.0, 65.0, 88.0, 93.0, 121.0, 99.0, 102.0, 72.0, 112.0, 112.0, 100.0, 84.0, 109.0, 63.0, 107.0, 115.0, 119.0, 75.0, 102.0, 80.0, 116.0, 99.0, 92.0, 85.0, 107.0, 98.0, 110.0, 118.0, 92.0, 122.0, 74.0, 117.0, 58.0, 96.0, 115.0, 66.0, 67.0, 116.0, 85.0, 62.0, 77.0, 164.0, 126.0, 94.0, 142.0, 96.0, 64.0, 97.0, 88.0, 989.0, 119.0, 80.0, 110.0, 84.0, 85.0, 117.0, 94.0, 72.0, 100.0, 85.0, 104.0, 102.0, 74.0, 79.0, 95.0, 98.0, 85.0, 86.0, 101.0, 977.0, 84.0, 93.0, 105.0, 104.0, 107.0, 112.0, 113.0, 72.0, 76.0, 104.0, 126.0, 83.0, 76.0, 105.0, 106.0, 109.0, 98.0, 76.0, 115.0, 97.0, 121.0, 83.0, 94.0, 113.0, 90.0, 59.0, 122.0, 109.0, 48.0, 82.0, 111.0, 77.0, 86.0, 117.0, 95.0, 98.0, 104.0, 87.0, 103.0, 123.0, 117.0, 114.0, 100.0, 140.0, 102.0, 128.0, 83.0, 106.0, 113.0, 76.0, 60.0, 84.0, 97.0, 74.0, 84.0, 100.0, 94.0, 78.0, 126.0, 98.0, 95.0, 125.0, 91.0, 117.0, 118.0, 138.0, 116.0, 96.0,
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.nunique()
# Out:
# state                       51
# account length             212
# area code                    3
# phone number              3333
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            120
# total day charge          1667
# total eve minutes         1611
# total eve calls            129
# total eve charge          1440
# total night minutes       1591
# total night calls          126
# total night charge         933
# total intl minutes         162
# total intl calls            22
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %%
df.reset_index(drop=True)
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['churn'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: churn, dtype: bool

# %%
df['churn'].unique()
# Out:
# array([False,  True])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['international plan'] = le.fit_transform(df['international plan'])
df
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657                   0
# 1       OH             107        415     371-7191                   0
# 2       NJ             137        415     358-1921                   0
# 3       OH              84        408     375-9999                   1
# 4       OK              75        415     330-6626                   1
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276                   0
# 3329    WV              68        415     370-3271                   0
# 3330    RI              28        510     328-8230                   0
# 3331    CT             184        510     364-6381                   1
# 3332    TN              74        415     400-4344                   0
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['voice mail plan'] = le.fit_transform(df['voice mail plan'])
df
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657                   0
# 1       OH             107        415     371-7191                   0
# 2       NJ             137        415     358-1921                   0
# 3       OH              84        408     375-9999                   1
# 4       OK              75        415     330-6626                   1
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276                   0
# 3329    WV              68        415     370-3271                   0
# 3330    RI              28        510     328-8230                   0
# 3331    CT             184        510     364-6381                   1
# 3332    TN              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['churn'] = le.fit_transform(df['churn'])
df
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657                   0
# 1       OH             107        415     371-7191                   0
# 2       NJ             137        415     358-1921                   0
# 3       OH              84        408     375-9999                   1
# 4       OK              75        415     330-6626                   1
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276                   0
# 3329    WV              68        415     370-3271                   0
# 3330    RI              28        510     328-8230                   0
# 3331    CT             184        510     364-6381                   1
# 3332    TN              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['state'] = le.fit_transform(df['state'])
df
# Out:
#       state  account length  area code phone number  international plan  \
# 0        16             128        415     382-4657                   0
# 1        35             107        415     371-7191                   0
# 2        31             137        415     358-1921                   0
# 3        35              84        408     375-9999                   1
# 4        36              75        415     330-6626                   1
# ...     ...             ...        ...          ...                 ...
# 3328      3             192        415     414-4276                   0
# 3329     49              68        415     370-3271                   0
# 3330     39              28        510     328-8230                   0
# 3331      6             184        510     364-6381                   1
# 3332     42              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.drop('phone number', axis=1,inplace=True)

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df['international plan'] = le.fit_transform('international plan')
# df['international plan'] = df['international plan'].map({'yes':1,'no':0})
# df['voice mail plan'] = df['voice mail plan'].map({'yes':1,'no':0})
# df['churn'] = df['churn'].map({'TRUE':1,'FALSE':0})

# %%
X = df.drop('churn', axis=1)
X
# Out:
#       state  account length  area code  international plan  voice mail plan  \
# 0        16             128        415                   0                1
# 1        35             107        415                   0                1
# 2        31             137        415                   0                0
# 3        35              84        408                   1                0
# 4        36              75        415                   1                0
# ...     ...             ...        ...                 ...              ...
# 3328      3             192        415                   0                1
# 3329     49              68        415                   0                0
# 3330     39              28        510                   0                0
# 3331      6             184        510                   1                0
# 3332     42              74        415                   0                1
#
# ...

# %%
X.columns
# Out:
# Index(['state', 'account length', 'area code', 'international plan',
#        'voice mail plan', 'number vmail messages', 'total day minutes',
#        'total day calls', 'total day charge', 'total eve minutes',
#        'total eve calls', 'total eve charge', 'total night minutes',
#        'total night calls', 'total night charge', 'total intl minutes',
#        'total intl calls', 'total intl charge', 'customer service calls'],
#       dtype='object')

# %%
Y=df["churn"]
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %%
X.dtypes
# Out:
# state                       int64
# account length              int64
# area code                   int64
# international plan          int64
# voice mail plan             int64
# number vmail messages       int64
# total day minutes         float64
# total day calls           float64
# total day charge          float64
# total eve minutes         float64
# total eve calls           float64
# total eve charge          float64
# total night minutes       float64
# total night calls         float64
# total night charge        float64
# total intl minutes        float64
# total intl calls          float64
# total intl charge         float64
# customer service calls      int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X1 = scaler.fit_transform(X)
X1
# Out:
# array([[-0.6786493 ,  0.67648946, -0.52360328, ..., -0.60089511,
#         -0.0856905 , -0.42793202],
#        [ 0.6031696 ,  0.14906505, -0.52360328, ..., -0.60089511,
#          1.2411686 , -0.42793202],
#        [ 0.33331299,  0.9025285 , -0.52360328, ...,  0.21202315,
#          0.69715637, -1.1882185 ],
#        ...,
#        [ 0.87302621, -1.83505538,  1.71881732, ...,  0.61848229,
#          1.3871231 ,  0.33235445],
#        [-1.35329082,  2.08295458,  1.71881732, ...,  2.24431883,
#         -1.87695028,  0.33235445],
#        [ 1.07541867, -0.67974475, -0.52360328, ..., -0.19443598,
#          1.2411686 , -1.1882185 ]], shape=(3333, 19))

# %%
X1 = pd.DataFrame(
    X1,
    columns=['state', 'account length', 'area code', 'international plan',
       'voice mail plan', 'number vmail messages', 'total day minutes',
       'total day calls', 'total day charge', 'total eve minutes',
       'total eve calls', 'total eve charge', 'total night minutes',
       'total night calls', 'total night charge', 'total intl minutes',
       'total intl calls', 'total intl charge', 'customer service calls']
)
X1
# Out:
#          state  account length  area code  international plan  \
# 0    -0.678649        0.676489  -0.523603           -0.327580
# 1     0.603170        0.149065  -0.523603           -0.327580
# 2     0.333313        0.902529  -0.523603           -0.327580
# 3     0.603170       -0.428590  -0.688834            3.052685
# 4     0.670634       -0.654629  -0.523603            3.052685
# ...        ...             ...        ...                 ...
# 3328 -1.555683        2.283878  -0.523603           -0.327580
# 3329  1.547668       -0.830437  -0.523603           -0.327580
# 3330  0.873026       -1.835055   1.718817           -0.327580
# 3331 -1.353291        2.082955   1.718817            3.052685
# 3332  1.075419       -0.679745  -0.523603           -0.327580
#
#       voice mail plan  number vmail messages  total day minutes  \
# 0            1.617086               1.234883           1.566767
# 1            1.617086               1.307948          -0.333738
# ...

# %%
X1.head()
# Out:
#       state  account length  area code  international plan  voice mail plan  \
# 0 -0.678649        0.676489  -0.523603           -0.327580         1.617086
# 1  0.603170        0.149065  -0.523603           -0.327580         1.617086
# 2  0.333313        0.902529  -0.523603           -0.327580        -0.618396
# 3  0.603170       -0.428590  -0.688834            3.052685        -0.618396
# 4  0.670634       -0.654629  -0.523603            3.052685        -0.618396
#
#    number vmail messages  total day minutes  total day calls  \
# 0               1.234883           1.566767         0.477820
# 1               1.307948          -0.333738         1.126267
# 2              -0.591760           1.168304         0.677342
# 3              -0.591760           2.196596        -1.467522
# 4              -0.591760          -0.240090         0.627462
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# ...

# %%
x2=pd.concat([X1,Y],axis=1)
x2
# Out:
#          state  account length  area code  international plan  \
# 0    -0.678649        0.676489  -0.523603           -0.327580
# 1     0.603170        0.149065  -0.523603           -0.327580
# 2     0.333313        0.902529  -0.523603           -0.327580
# 3     0.603170       -0.428590  -0.688834            3.052685
# 4     0.670634       -0.654629  -0.523603            3.052685
# ...        ...             ...        ...                 ...
# 3328 -1.555683        2.283878  -0.523603           -0.327580
# 3329  1.547668       -0.830437  -0.523603           -0.327580
# 3330  0.873026       -1.835055   1.718817           -0.327580
# 3331 -1.353291        2.082955   1.718817            3.052685
# 3332  1.075419       -0.679745  -0.523603           -0.327580
#
#       voice mail plan  number vmail messages  total day minutes  \
# 0            1.617086               1.234883           1.566767
# 1            1.617086               1.307948          -0.333738
# ...

# %%
X = x2.drop('churn', axis=1)
Y = x2['churn']
X
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)
X_train,X_test
# Out:
# (         state  account length  area code  international plan  \
#  817   1.210347        3.564766   1.718817           -0.327580
#  1373  0.940490        0.174180  -0.523603           -0.327580
#  679   1.142883       -0.654629  -0.523603            3.052685
#  56   -1.420755        1.002990  -0.523603           -0.327580
#  1993 -0.746113       -0.378359   1.718817           -0.327580
#  ...        ...             ...        ...                 ...
#  1095 -0.881042        0.123950   1.718817           -0.327580
#  1130  0.805562        0.525797  -0.523603           -0.327580
#  1294  0.738098       -0.880668  -0.688834           -0.327580
#  860  -1.015970        1.706223  -0.523603           -0.327580
#  3174  0.940490       -1.634132  -0.688834           -0.327580
#
#        voice mail plan  number vmail messages  total day minutes  \
#  817         -0.618396              -0.591760          -1.547490
#  1373        -0.618396              -0.591760          -1.244511
# ...

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2666, 19)
# (667, 19)
# (2666,)
# (667,)

# %%
print(X_train)
# Out:
#          state  account length  area code  international plan  \
# 817   1.210347        3.564766   1.718817           -0.327580
# 1373  0.940490        0.174180  -0.523603           -0.327580
# 679   1.142883       -0.654629  -0.523603            3.052685
# 56   -1.420755        1.002990  -0.523603           -0.327580
# 1993 -0.746113       -0.378359   1.718817           -0.327580
# ...        ...             ...        ...                 ...
# 1095 -0.881042        0.123950   1.718817           -0.327580
# 1130  0.805562        0.525797  -0.523603           -0.327580
# 1294  0.738098       -0.880668  -0.688834           -0.327580
# 860  -1.015970        1.706223  -0.523603           -0.327580
# 3174  0.940490       -1.634132  -0.688834           -0.327580
#
#       voice mail plan  number vmail messages  total day minutes  \
# 817         -0.618396              -0.591760          -1.547490
# 1373        -0.618396              -0.591760          -1.244511
# ...

# %%
print(X_test)
# Out:
#          state  account length  area code  international plan  \
# 438   1.615132        0.299758   1.718817            -0.32758
# 2674 -0.813578       -0.855553  -0.523603            -0.32758
# 1345  1.007955       -0.076974  -0.523603            -0.32758
# 1957 -0.611185        1.153683  -0.688834            -0.32758
# 2148  1.615132       -0.127205  -0.688834            -0.32758
# ...        ...             ...        ...                 ...
# 2577 -0.206400        1.404837   1.718817            -0.32758
# 2763  0.063456        0.375104  -0.688834            -0.32758
# 3069 -0.746113        1.178798  -0.523603            -0.32758
# 1468  0.603170       -0.654629   1.718817            -0.32758
# 582   0.400777        0.073719  -0.523603            -0.32758
#
#       voice mail plan  number vmail messages  total day minutes  \
# 438         -0.618396              -0.591760          -0.454929
# 2674        -0.618396              -0.591760          -1.297762
# ...

# %%
y_train.head()
# Out:
# 817     0
# 1373    1
# 679     1
# 56      0
# 1993    0
# Name: churn, dtype: int64

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)

# %%
print(X_train)
# Out:
#          state  account length  area code  international plan  \
# 817   1.210347        3.564766   1.718817           -0.327580
# 1373  0.940490        0.174180  -0.523603           -0.327580
# 679   1.142883       -0.654629  -0.523603            3.052685
# 56   -1.420755        1.002990  -0.523603           -0.327580
# 1993 -0.746113       -0.378359   1.718817           -0.327580
# ...        ...             ...        ...                 ...
# 1095 -0.881042        0.123950   1.718817           -0.327580
# 1130  0.805562        0.525797  -0.523603           -0.327580
# 1294  0.738098       -0.880668  -0.688834           -0.327580
# 860  -1.015970        1.706223  -0.523603           -0.327580
# 3174  0.940490       -1.634132  -0.688834           -0.327580
#
#       voice mail plan  number vmail messages  total day minutes  \
# 817         -0.618396              -0.591760          -1.547490
# 1373        -0.618396              -0.591760          -1.244511
# ...

# %%
# pip install xgboost

# %%
# pip install xgboost

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print(X_test)
# Out:
#          state  account length  area code  international plan  \
# 438   1.615132        0.299758   1.718817            -0.32758
# 2674 -0.813578       -0.855553  -0.523603            -0.32758
# 1345  1.007955       -0.076974  -0.523603            -0.32758
# 1957 -0.611185        1.153683  -0.688834            -0.32758
# 2148  1.615132       -0.127205  -0.688834            -0.32758
# ...        ...             ...        ...                 ...
# 2577 -0.206400        1.404837   1.718817            -0.32758
# 2763  0.063456        0.375104  -0.688834            -0.32758
# 3069 -0.746113        1.178798  -0.523603            -0.32758
# 1468  0.603170       -0.654629   1.718817            -0.32758
# 582   0.400777        0.073719  -0.523603            -0.32758
#
#       voice mail plan  number vmail messages  total day minutes  \
# 438         -0.618396              -0.591760          -0.454929
# 2674        -0.618396              -0.591760          -1.297762
# ...

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, Y_pred)

print(accuracy)
# Out:
# 0.952023988005997

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, Y_pred))
# Out:
# [[560   6]
#  [ 26  75]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       566
#            1       0.93      0.74      0.82       101
#
#     accuracy                           0.95       667
#    macro avg       0.94      0.87      0.90       667
# weighted avg       0.95      0.95      0.95       667

# %%
X.head()
# Out:
#       state  account length  area code  international plan  voice mail plan  \
# 0 -0.678649        0.676489  -0.523603           -0.327580         1.617086
# 1  0.603170        0.149065  -0.523603           -0.327580         1.617086
# 2  0.333313        0.902529  -0.523603           -0.327580        -0.618396
# 3  0.603170       -0.428590  -0.688834            3.052685        -0.618396
# 4  0.670634       -0.654629  -0.523603            3.052685        -0.618396
#
#    number vmail messages  total day minutes  total day calls  \
# 0               1.234883           1.566767         0.477820
# 1               1.307948          -0.333738         1.126267
# 2              -0.591760           1.168304         0.677342
# 3              -0.591760           2.196596        -1.467522
# 4              -0.591760          -0.240090         0.627462
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# ...

# %%
X.tail()
# Out:
#          state  account length  area code  international plan  \
# 3328 -1.555683        2.283878  -0.523603           -0.327580
# 3329  1.547668       -0.830437  -0.523603           -0.327580
# 3330  0.873026       -1.835055   1.718817           -0.327580
# 3331 -1.353291        2.082955   1.718817            3.052685
# 3332  1.075419       -0.679745  -0.523603           -0.327580
#
#       voice mail plan  number vmail messages  total day minutes  \
# 3328         1.617086               2.038605          -0.432895
# 3329        -0.618396              -0.591760           0.942447
# 3330        -0.618396              -0.591760           0.018820
# 3331        -0.618396              -0.591760           0.624778
# 3332         1.617086               1.234883           1.003042
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# 3328        -1.168239         -0.433386           0.286348         0.833991
# ...

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: churn, dtype: int64

# %%
Y.tail()
# Out:
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, dtype: int64

# %%
X.loc[679]
# Out:
# state                     1.142883
# account length           -0.654629
# area code                -0.523603
# international plan        3.052685
# voice mail plan          -0.618396
# number vmail messages    -0.591760
# total day minutes         0.782694
# total day calls          -1.118358
# total day charge          0.782853
# total eve minutes         2.485289
# total eve calls           0.339284
# total eve charge          2.486405
# total night minutes       0.140963
# total night calls         0.118752
# total night charge        0.140923
# total intl minutes       -0.550721
# total intl calls          1.837860
# total intl charge        -0.550091
# customer service calls   -0.427932
# Name: 679, dtype: float64

# %%
Y.loc[679]

# %%
model.predict([[-0.678649,	0.676489,	-0.523603,	-0.327580,	1.617086,	1.234883,	1.566767	,0.477820,	1.567036	,-0.070610,	-0.056481,
               -0.070427	,0.866743,	-0.350248,	0.866029,	-0.085008,	-0.600895,	-0.085690	,-0.427932]])
# Out:
# array([0])

# %%
model.predict([[ 1.14288   ,        -0.654629,
                -0.523603,
      3.052685,         -0.618396,
   -0.591760,
       0.782694,
         -1.118358,
        0.782853,
        2.485289,
           0.339284,
          2.486405,
       0.140963,
         0.118752,
        0.140923,
     -0.550721,
          1.837860,
        -0.550091,  -0.427932]])
# Out:
# array([1])
